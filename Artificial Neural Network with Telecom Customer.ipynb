# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Telco-Customer-Churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.drop('customerID' , axis = 'columns' , inplace =True)

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
df.MonthlyCharges.values
# Out:
# array([ 29.85,  56.95,  53.85, ...,  29.6 ,  74.4 , 105.65])

# %%
#pd.to_numeric(df.TotalCharges)

# %%
pd.to_numeric(df.TotalCharges , errors = 'coerce')
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %%
pd.to_numeric(df.TotalCharges , errors = 'coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %%
df[pd.to_numeric(df.TotalCharges , errors = 'coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# 753                 No              No  No internet service
# 936                 No             DSL                  Yes
# 1082               Yes              No  No internet service
# 1340  No phone service             DSL                  Yes
# 3331                No              No  No internet service
# 3826               Yes              No  No internet service
# 4380                No              No  No internet service
# 5218                No              No  No internet service
# 6670               Yes             DSL                   No
# 6754               Yes             DSL                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 488                    No                  Yes                  Yes
# 753   No internet service  No internet service  No internet service
# 936                   Yes                  Yes                   No
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                  Yes                  Yes                  Yes
# 6754                  Yes                   No                  Yes
#
#               StreamingTV      StreamingMovies  Contract PaperlessBilling  \
# 488                   Yes                   No  Two year              Yes
# 753   No internet service  No internet service  Two year               No
# 936                   Yes                  Yes  Two year               No
# 1082  No internet service  No internet service  Two year               No
# 1340                  Yes                   No  Two year               No
# 3331  No internet service  No internet service  Two year               No
# 3826  No internet service  No internet service  Two year               No
# 4380  No internet service  No internet service  Two year               No
# 5218  No internet service  No internet service  One year              Yes
# 6670                  Yes                   No  Two year               No
# 6754                   No                   No  Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 488   Bank transfer (automatic)           52.55                 No
# 753                Mailed check           20.25                 No
# 936                Mailed check           80.85                 No
# 1082               Mailed check           25.75                 No
# 1340    Credit card (automatic)           56.05                 No
# 3331               Mailed check           19.85                 No
# 3826               Mailed check           25.35                 No
# 4380               Mailed check           20.00                 No
# 5218               Mailed check           19.70                 No
# 6670               Mailed check           73.35                 No
# 6754  Bank transfer (automatic)           61.90                 No

# %%
df.shape
# Out:
# (7043, 20)

# %%
df.iloc[488]['TotalCharges']
# Out:
# ' '

# %%
df1 = df[df.TotalCharges!=' ']

# %%
df1.shape
# Out:
# (7032, 20)

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
pd.to_numeric(df1.TotalCharges)
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7032, dtype: float64

# %%
df1.TotalCharges = pd.to_numeric(df1.TotalCharges)

# %%
df1.TotalCharges.dtypes
# Out:
# dtype('float64')

# %%
df1[df1.Churn=='No']
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 3       Male              0      No         No      45           No
# 6       Male              0      No        Yes      22          Yes
# 7     Female              0      No         No      10           No
# ...      ...            ...     ...        ...     ...          ...
# 7037  Female              0      No         No      72          Yes
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 0     No phone service             DSL                   No
# 1                   No             DSL                  Yes
# 3     No phone service             DSL                  Yes
# 6                  Yes     Fiber optic                   No
# 7     No phone service             DSL                  Yes
# ...                ...             ...                  ...
# 7037                No              No  No internet service
# 7038               Yes             DSL                  Yes
# 7039               Yes     Fiber optic                   No
# 7040  No phone service             DSL                  Yes
# 7042                No     Fiber optic                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 0                     Yes                   No                   No
# 1                      No                  Yes                   No
# 3                      No                  Yes                  Yes
# 6                     Yes                   No                   No
# 7                      No                   No                   No
# ...                   ...                  ...                  ...
# 7037  No internet service  No internet service  No internet service
# 7038                   No                  Yes                  Yes
# 7039                  Yes                  Yes                   No
# 7040                   No                   No                   No
# 7042                   No                  Yes                  Yes
#
#               StreamingTV      StreamingMovies        Contract  \
# 0                      No                   No  Month-to-month
# 1                      No                   No        One year
# 3                      No                   No        One year
# 6                     Yes                   No  Month-to-month
# 7                      No                   No  Month-to-month
# ...                   ...                  ...             ...
# 7037  No internet service  No internet service        Two year
# 7038                  Yes                  Yes        One year
# 7039                  Yes                  Yes        One year
# 7040                   No                   No  Month-to-month
# 7042                  Yes                  Yes        Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 0                 Yes           Electronic check           29.85
# 1                  No               Mailed check           56.95
# 3                  No  Bank transfer (automatic)           42.30
# 6                 Yes    Credit card (automatic)           89.10
# 7                  No               Mailed check           29.75
# ...               ...                        ...             ...
# 7037              Yes  Bank transfer (automatic)           21.15
# 7038              Yes               Mailed check           84.80
# 7039              Yes    Credit card (automatic)          103.20
# 7040              Yes           Electronic check           29.60
# 7042              Yes  Bank transfer (automatic)          105.65
#
#       TotalCharges Churn
# 0            29.85    No
# 1          1889.50    No
# 3          1840.75    No
# 6          1949.40    No
# 7           301.90    No
# ...            ...   ...
# 7037       1419.40    No
# 7038       1990.50    No
# 7039       7362.90    No
# 7040        346.45    No
# 7042       6844.50    No
#
# [5163 rows x 20 columns]

# %%
tenure_churn_no = df1[df1.Churn=='No'].tenure
tenure_churn_yes = df1[df1.Churn=='Yes'].tenure

# %%
tenure_churn_no = df1[df1.Churn=='No'].tenure
tenure_churn_yes = df1[df1.Churn=='Yes'].tenure

plt.xlabel('tenure')
plt.ylabel('Number of Customers')
plt.title('Customer Churn prediction visualization')

plt.hist([tenure_churn_yes,tenure_churn_no], color =['g' , 'r'] , label =['Churn=Yes','Churn=No'])
plt.legend()

# %%
mc_churn_no = df1[df1.Churn=='No'].MonthlyCharges
mc_churn_yes = df1[df1.Churn=='Yes'].MonthlyCharges

plt.xlabel('MonthlyCharges')
plt.ylabel('Number of Customers')
plt.title('Customer Churn prediction visualization')

blood_sugar_men = [113 , 85,90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67 , 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]


plt.hist([mc_churn_yes,mc_churn_no], rwidth = 0.95 , color =['g' , 'r'] , label =['Churn=Yes','Churn=No'])
plt.legend()

# %%
for column in df:
    print(f'{column} : {df[column].unique()}')
# Out:
# gender : ['Female' 'Male']
# SeniorCitizen : [0 1]
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# tenure : [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26  0
#  39]
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No phone service' 'No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes' 'No internet service']
# OnlineBackup : ['Yes' 'No' 'No internet service']
# DeviceProtection : ['No' 'Yes' 'No internet service']
# TechSupport : ['No' 'Yes' 'No internet service']
# StreamingTV : ['No' 'Yes' 'No internet service']
# StreamingMovies : ['No' 'Yes' 'No internet service']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges : [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges : ['29.85' '1889.5' '108.15' ... '346.45' '306.6' '6844.5']
# Churn : ['No' 'Yes']

# %%
def print_unique_col_values(df):
    for column in df:
        if df[column].dtypes == 'object':
            print(f'{column} : {df[column].unique()}')

# %%
print_unique_col_values(df1)
# Out:
# gender : ['Female' 'Male']
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No phone service' 'No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes' 'No internet service']
# OnlineBackup : ['Yes' 'No' 'No internet service']
# DeviceProtection : ['No' 'Yes' 'No internet service']
# TechSupport : ['No' 'Yes' 'No internet service']
# StreamingTV : ['No' 'Yes' 'No internet service']
# StreamingMovies : ['No' 'Yes' 'No internet service']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn : ['No' 'Yes']

# %%
df1.replace('No internet service' , 'No' ,inplace= True)
df1.replace('No phone service' , 'No' ,inplace= True)

# %%
print_unique_col_values(df1)
# Out:
# gender : ['Female' 'Male']
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes']
# OnlineBackup : ['Yes' 'No']
# DeviceProtection : ['No' 'Yes']
# TechSupport : ['No' 'Yes']
# StreamingTV : ['No' 'Yes']
# StreamingMovies : ['No' 'Yes']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn : ['No' 'Yes']

# %%
yes_no_columns = ['Partner' ,'Dependents','PhoneService', 'MultipleLines' ,'OnlineSecurity', 'OnlineBackup' ,
                  'DeviceProtection' ,'TechSupport',
                 'StreamingTV' , 'StreamingMovies' ,'PaperlessBilling' ,'Churn']

# %%
for col in yes_no_columns:
    df1[col].replace({'Yes': 1 , 'No' : 0},inplace=True)

# %%
for col in df1:
    print(f'{col}: {df1[col].unique()}')
# Out:
# gender: ['Female' 'Male']
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]

# %%
df1['gender'].replace({'Female':1 , 'Male':0} ,inplace=True)

# %%
df1['gender'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df2 = pd.get_dummies(data=df1,columns=['InternetService' , 'Contract' ,'PaymentMethod'])
df2.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
df2.sample(4)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 5385       0              0        0           0      53             1
# 1613       0              0        0           0      34             1
# 668        1              0        0           0       4             1
# 1760       0              0        1           1      50             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 5385              1               0             0                 0  ...
# 1613              0               0             0                 0  ...
# 668               0               0             0                 0  ...
# 1760              1               0             0                 1  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 5385                    0                            1                   0
# 1613                    0                            0                   1
# 668                     1                            0                   0
# 1760                    1                            0                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 5385                        1                  0                  0
# 1613                        1                  0                  0
# 668                         1                  0                  0
# 1760                        0                  1                  0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 5385                                        1
# 1613                                        0
# 668                                         0
# 1760                                        1
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 5385                                      0                               0
# 1613                                      0                               0
# 668                                       0                               0
# 1760                                      0                               0
#
#       PaymentMethod_Mailed check
# 5385                           0
# 1613                           1
# 668                            1
# 1760                           0
#
# [4 rows x 27 columns]

# %%
df2.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                          uint8
# InternetService_Fiber optic                  uint8
# InternetService_No                           uint8
# Contract_Month-to-month                      uint8
# Contract_One year                            uint8
# Contract_Two year                            uint8
# PaymentMethod_Bank transfer (automatic)      uint8
# PaymentMethod_Credit card (automatic)        uint8
# PaymentMethod_Electronic check               uint8
# PaymentMethod_Mailed check                   uint8
# dtype: object

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
cols_to_scale = ['tenure', 'MonthlyCharges', 'TotalCharges']

# %%
df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])

# %%
df2.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 3249       1              0        1           1  0.126761             1
# 6417       1              1        1           0  0.704225             1
# 4798       1              1        0           0  0.492958             1
# 3599       1              0        1           1  0.619718             1
# 1489       1              0        1           1  0.309859             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 3249              0               0             1                 1  ...
# 6417              1               1             0                 0  ...
# 4798              1               0             0                 0  ...
# 3599              1               1             1                 1  ...
# 1489              0               1             1                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 3249                    1                            0                   0
# 6417                    0                            1                   0
# 4798                    0                            1                   0
# 3599                    1                            0                   0
# 1489                    1                            0                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 3249                        1                  0                  0
# 6417                        1                  0                  0
# 4798                        1                  0                  0
# 3599                        1                  0                  0
# 1489                        0                  1                  0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 3249                                        0
# 6417                                        0
# 4798                                        1
# 3599                                        0
# 1489                                        0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 3249                                      0                               0
# 6417                                      0                               1
# 4798                                      0                               0
# 3599                                      0                               0
# 1489                                      0                               0
#
#       PaymentMethod_Mailed check
# 3249                           1
# 6417                           0
# 4798                           0
# 3599                           1
# 1489                           1
#
# [5 rows x 27 columns]

# %%
for col in df2:
    print(f'{col}: {df2[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# PaperlessBilling: [1 0]
# MonthlyCharges: [0.11542289 0.38507463 0.35422886 ... 0.44626866 0.25820896 0.60149254]
# TotalCharges: [0.0012751  0.21586661 0.01031041 ... 0.03780868 0.03321025 0.78764136]
# Churn: [0 1]
# InternetService_DSL: [1 0]
# InternetService_Fiber optic: [0 1]
# InternetService_No: [0 1]
# Contract_Month-to-month: [1 0]
# Contract_One year: [0 1]
# Contract_Two year: [0 1]
# PaymentMethod_Bank transfer (automatic): [0 1]
# PaymentMethod_Credit card (automatic): [0 1]
# PaymentMethod_Electronic check: [1 0]
# PaymentMethod_Mailed check: [0 1]

# %%
x = df2.drop('Churn' ,axis ='columns')
y = df2['Churn']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train, y_test = train_test_split(x, y , test_size = 0.33 ,random_state = 42)

# %%
x_train.shape
# Out:
# (4711, 26)

# %%
x_test.shape
# Out:
# (2321, 26)

# %%
x_train[:10]
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 5767       1              0        1           0  0.901408             1
# 5361       1              0        0           1  0.042254             1
# 5745       1              0        1           1  0.845070             1
# 6065       0              0        0           0  0.816901             1
# 229        1              0        1           1  0.647887             1
# 3657       1              0        1           1  0.507042             1
# 5429       1              0        1           1  1.000000             1
# 4874       1              0        0           0  0.521127             1
# 5940       0              0        1           1  0.774648             1
# 4519       1              0        1           0  0.788732             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 5767              0               0             0                 0  ...
# 5361              0               0             0                 0  ...
# 5745              1               0             0                 0  ...
# 6065              1               0             0                 0  ...
# 229               1               1             1                 0  ...
# 3657              1               0             0                 0  ...
# 5429              1               1             1                 1  ...
# 4874              0               1             1                 1  ...
# 5940              0               0             1                 1  ...
# 4519              1               0             1                 1  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 5767                    1                            0                   0
# 5361                    0                            0                   1
# 5745                    0                            0                   1
# 6065                    0                            0                   1
# 229                     1                            0                   0
# 3657                    0                            0                   1
# 5429                    1                            0                   0
# 4874                    0                            1                   0
# 5940                    0                            1                   0
# 4519                    0                            1                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 5767                        0                  0                  1
# 5361                        0                  1                  0
# 5745                        0                  0                  1
# 6065                        0                  0                  1
# 229                         0                  0                  1
# 3657                        0                  0                  1
# 5429                        0                  0                  1
# 4874                        1                  0                  0
# 5940                        0                  1                  0
# 4519                        0                  1                  0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 5767                                        0
# 5361                                        0
# 5745                                        0
# 6065                                        0
# 229                                         0
# 3657                                        1
# 5429                                        1
# 4874                                        0
# 5940                                        0
# 4519                                        1
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 5767                                      1                               0
# 5361                                      0                               0
# 5745                                      0                               0
# 6065                                      0                               0
# 229                                       1                               0
# 3657                                      0                               0
# 5429                                      0                               0
# 4874                                      1                               0
# 5940                                      0                               0
# 4519                                      0                               0
#
#       PaymentMethod_Mailed check
# 5767                           0
# 5361                           1
# 5745                           1
# 6065                           1
# 229                            0
# 3657                           0
# 5429                           0
# 4874                           0
# 5940                           1
# 4519                           0
#
# [10 rows x 26 columns]

# %%
len(x_train.columns)
# Out:
# 26

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model = keras.Sequential([
    keras.layers.Dense(20, input_shape=(26,), activation = 'relu'),
    keras.layers.Dense(1,  activation = 'sigmoid'),
])

# %%
model.compile(optimizer='adam' ,loss ='binary_crossentropy',metrics =['accuracy'])

# %%
model.fit(x_train , y_train, epochs =100)
# Out:
# Epoch 1/100
# 148/148 [==============================] - 0s 762us/step - loss: 0.5560 - accuracy: 0.7047
# Epoch 2/100
# 148/148 [==============================] - 0s 687us/step - loss: 0.4513 - accuracy: 0.7778
# Epoch 3/100
# 148/148 [==============================] - 0s 782us/step - loss: 0.4294 - accuracy: 0.7903
# Epoch 4/100
# 148/148 [==============================] - 0s 762us/step - loss: 0.4248 - accuracy: 0.7947
# Epoch 5/100
# 148/148 [==============================] - 0s 844us/step - loss: 0.4201 - accuracy: 0.7988
# Epoch 6/100
# 148/148 [==============================] - 0s 735us/step - loss: 0.4190 - accuracy: 0.7992
# Epoch 7/100
# 148/148 [==============================] - 0s 801us/step - loss: 0.4177 - accuracy: 0.8003
# Epoch 8/100
# 148/148 [==============================] - 0s 721us/step - loss: 0.4166 - accuracy: 0.8022
# Epoch 9/100
# 148/148 [==============================] - 0s 741us/step - loss: 0.4152 - accuracy: 0.8030
# Epoch 10/100
# 148/148 [==============================] - 0s 748us/step - loss: 0.4142 - accuracy: 0.8032
# Epoch 11/100
# 148/148 [==============================] - 0s 783us/step - loss: 0.4132 - accuracy: 0.8047
# Epoch 12/100
# 148/148 [==============================] - 0s 796us/step - loss: 0.4123 - accuracy: 0.8037
# Epoch 13/100
# 148/148 [==============================] - 0s 725us/step - loss: 0.4118 - accuracy: 0.8058
# Epoch 14/100
# 148/148 [==============================] - 0s 819us/step - loss: 0.4108 - accuracy: 0.8070
# Epoch 15/100
# 148/148 [==============================] - 0s 762us/step - loss: 0.4109 - accuracy: 0.8045
# Epoch 16/100
# 148/148 [==============================] - 0s 782us/step - loss: 0.4102 - accuracy: 0.8047
# Epoch 17/100
# 148/148 [==============================] - 0s 728us/step - loss: 0.4088 - accuracy: 0.8068
# Epoch 18/100
# 148/148 [==============================] - 0s 707us/step - loss: 0.4080 - accuracy: 0.8102
# Epoch 19/100
# 148/148 [==============================] - 0s 721us/step - loss: 0.4079 - accuracy: 0.8075
# Epoch 20/100
# 148/148 [==============================] - 0s 718us/step - loss: 0.4067 - accuracy: 0.8094
# Epoch 21/100
# 148/148 [==============================] - 0s 789us/step - loss: 0.4064 - accuracy: 0.8087
# Epoch 22/100
# 148/148 [==============================] - 0s 727us/step - loss: 0.4058 - accuracy: 0.8092
# Epoch 23/100
# 148/148 [==============================] - 0s 754us/step - loss: 0.4054 - accuracy: 0.8119
# Epoch 24/100
# 148/148 [==============================] - 0s 742us/step - loss: 0.4044 - accuracy: 0.8077
# Epoch 25/100
# 148/148 [==============================] - 0s 857us/step - loss: 0.4042 - accuracy: 0.8126
# Epoch 26/100
# 148/148 [==============================] - 0s 741us/step - loss: 0.4035 - accuracy: 0.8109
# Epoch 27/100
# 148/148 [==============================] - 0s 727us/step - loss: 0.4028 - accuracy: 0.8132
# Epoch 28/100
# 148/148 [==============================] - 0s 748us/step - loss: 0.4026 - accuracy: 0.8138
# Epoch 29/100
# 148/148 [==============================] - 0s 721us/step - loss: 0.4020 - accuracy: 0.8115
# Epoch 30/100
# 148/148 [==============================] - 0s 803us/step - loss: 0.4015 - accuracy: 0.8126
# Epoch 31/100
# 148/148 [==============================] - 0s 729us/step - loss: 0.4008 - accuracy: 0.8126
# Epoch 32/100
# 148/148 [==============================] - 0s 782us/step - loss: 0.4006 - accuracy: 0.8141
# Epoch 33/100
# 148/148 [==============================] - 0s 742us/step - loss: 0.3996 - accuracy: 0.8138
# Epoch 34/100
# 148/148 [==============================] - 0s 857us/step - loss: 0.3998 - accuracy: 0.8121
# Epoch 35/100
# 148/148 [==============================] - 0s 741us/step - loss: 0.3991 - accuracy: 0.8147
# Epoch 36/100
# 148/148 [==============================] - 0s 782us/step - loss: 0.3986 - accuracy: 0.8160
# Epoch 37/100
# 148/148 [==============================] - 0s 742us/step - loss: 0.3986 - accuracy: 0.8143
# Epoch 38/100
# 148/148 [==============================] - 0s 713us/step - loss: 0.3975 - accuracy: 0.8155
# Epoch 39/100
# 148/148 [==============================] - 0s 721us/step - loss: 0.3972 - accuracy: 0.8158
# Epoch 40/100
# 148/148 [==============================] - 0s 756us/step - loss: 0.3965 - accuracy: 0.8149
# Epoch 41/100
# 148/148 [==============================] - 0s 803us/step - loss: 0.3960 - accuracy: 0.8162
# Epoch 42/100
# 148/148 [==============================] - 0s 729us/step - loss: 0.3963 - accuracy: 0.8141
# Epoch 43/100
# 148/148 [==============================] - 0s 770us/step - loss: 0.3958 - accuracy: 0.8145
# Epoch 44/100
# 148/148 [==============================] - 0s 721us/step - loss: 0.3947 - accuracy: 0.8170
# Epoch 45/100
# 148/148 [==============================] - 0s 713us/step - loss: 0.3945 - accuracy: 0.8153
# Epoch 46/100
# 148/148 [==============================] - 0s 721us/step - loss: 0.3937 - accuracy: 0.8164
# Epoch 47/100
# 148/148 [==============================] - 0s 747us/step - loss: 0.3939 - accuracy: 0.8177
# Epoch 48/100
# 148/148 [==============================] - 0s 717us/step - loss: 0.3940 - accuracy: 0.8143
# Epoch 49/100
# 148/148 [==============================] - 0s 782us/step - loss: 0.3927 - accuracy: 0.8170
# Epoch 50/100
# 148/148 [==============================] - 0s 736us/step - loss: 0.3921 - accuracy: 0.8194
# Epoch 51/100
# 148/148 [==============================] - 0s 735us/step - loss: 0.3915 - accuracy: 0.8155
# Epoch 52/100
# 148/148 [==============================] - 0s 747us/step - loss: 0.3907 - accuracy: 0.8191
# Epoch 53/100
# 148/148 [==============================] - 0s 715us/step - loss: 0.3906 - accuracy: 0.8206
# Epoch 54/100
# 148/148 [==============================] - 0s 745us/step - loss: 0.3906 - accuracy: 0.8166
# Epoch 55/100
# 148/148 [==============================] - 0s 735us/step - loss: 0.3902 - accuracy: 0.8196
# Epoch 56/100
# 148/148 [==============================] - 0s 728us/step - loss: 0.3896 - accuracy: 0.8196
# Epoch 57/100
# 148/148 [==============================] - 0s 678us/step - loss: 0.3889 - accuracy: 0.8204
# Epoch 58/100
# 148/148 [==============================] - 0s 762us/step - loss: 0.3886 - accuracy: 0.8174
# Epoch 59/100
# 148/148 [==============================] - 0s 688us/step - loss: 0.3883 - accuracy: 0.8204
# Epoch 60/100
# 148/148 [==============================] - 0s 748us/step - loss: 0.3877 - accuracy: 0.8200
# Epoch 61/100
# 148/148 [==============================] - 0s 698us/step - loss: 0.3877 - accuracy: 0.8179
# Epoch 62/100
# 148/148 [==============================] - 0s 725us/step - loss: 0.3876 - accuracy: 0.8189
# Epoch 63/100
# 148/148 [==============================] - 0s 680us/step - loss: 0.3859 - accuracy: 0.8219
# Epoch 64/100
# 148/148 [==============================] - 0s 687us/step - loss: 0.3866 - accuracy: 0.8187
# Epoch 65/100
# 148/148 [==============================] - 0s 680us/step - loss: 0.3859 - accuracy: 0.8200
# Epoch 66/100
# 148/148 [==============================] - 0s 694us/step - loss: 0.3860 - accuracy: 0.8194
# Epoch 67/100
# 148/148 [==============================] - 0s 746us/step - loss: 0.3855 - accuracy: 0.8221
# Epoch 68/100
# 148/148 [==============================] - 0s 900us/step - loss: 0.3845 - accuracy: 0.8202
# Epoch 69/100
# 148/148 [==============================] - 0s 708us/step - loss: 0.3846 - accuracy: 0.8219
# Epoch 70/100
# 148/148 [==============================] - 0s 864us/step - loss: 0.3839 - accuracy: 0.8211
# Epoch 71/100
# 148/148 [==============================] - 0s 680us/step - loss: 0.3838 - accuracy: 0.8191
# Epoch 72/100
# 148/148 [==============================] - 0s 775us/step - loss: 0.3836 - accuracy: 0.8215
# Epoch 73/100
# 148/148 [==============================] - 0s 708us/step - loss: 0.3827 - accuracy: 0.8208
# Epoch 74/100
# 148/148 [==============================] - 0s 673us/step - loss: 0.3822 - accuracy: 0.8208
# Epoch 75/100
# 148/148 [==============================] - 0s 667us/step - loss: 0.3826 - accuracy: 0.8202
# Epoch 76/100
# 148/148 [==============================] - 0s 762us/step - loss: 0.3817 - accuracy: 0.8191
# Epoch 77/100
# 148/148 [==============================] - 0s 684us/step - loss: 0.3822 - accuracy: 0.8211
# Epoch 78/100
# 148/148 [==============================] - 0s 773us/step - loss: 0.3819 - accuracy: 0.8194
# Epoch 79/100
# 148/148 [==============================] - 0s 722us/step - loss: 0.3818 - accuracy: 0.8225
# Epoch 80/100
# 148/148 [==============================] - 0s 755us/step - loss: 0.3805 - accuracy: 0.8213
# Epoch 81/100
# 148/148 [==============================] - 0s 701us/step - loss: 0.3803 - accuracy: 0.8213
# Epoch 82/100
# 148/148 [==============================] - 0s 667us/step - loss: 0.3797 - accuracy: 0.8200
# Epoch 83/100
# 148/148 [==============================] - 0s 680us/step - loss: 0.3800 - accuracy: 0.8221
# Epoch 84/100
# 148/148 [==============================] - 0s 776us/step - loss: 0.3797 - accuracy: 0.8202
# Epoch 85/100
# 148/148 [==============================] - 0s 857us/step - loss: 0.3798 - accuracy: 0.8215
# Epoch 86/100
# 148/148 [==============================] - 0s 878us/step - loss: 0.3789 - accuracy: 0.8200
# Epoch 87/100
# 148/148 [==============================] - 0s 1ms/step - loss: 0.3788 - accuracy: 0.8213
# Epoch 88/100
# 148/148 [==============================] - 0s 1ms/step - loss: 0.3789 - accuracy: 0.8234
# Epoch 89/100
# 148/148 [==============================] - 0s 1ms/step - loss: 0.3784 - accuracy: 0.8215
# Epoch 90/100
# 148/148 [==============================] - 0s 1ms/step - loss: 0.3783 - accuracy: 0.8223
# Epoch 91/100
# 148/148 [==============================] - 0s 945us/step - loss: 0.3784 - accuracy: 0.8208
# Epoch 92/100
# 148/148 [==============================] - 0s 871us/step - loss: 0.3776 - accuracy: 0.8219
# Epoch 93/100
# 148/148 [==============================] - 0s 864us/step - loss: 0.3779 - accuracy: 0.8228
# Epoch 94/100
# 148/148 [==============================] - 0s 1ms/step - loss: 0.3771 - accuracy: 0.8211
# Epoch 95/100
# 148/148 [==============================] - 0s 973us/step - loss: 0.3764 - accuracy: 0.8236
# Epoch 96/100
# 148/148 [==============================] - 0s 1ms/step - loss: 0.3764 - accuracy: 0.8215
# Epoch 97/100
# 148/148 [==============================] - 0s 1ms/step - loss: 0.3766 - accuracy: 0.8211
# Epoch 98/100
# 148/148 [==============================] - 0s 1ms/step - loss: 0.3767 - accuracy: 0.8219
# Epoch 99/100
# 148/148 [==============================] - 0s 993us/step - loss: 0.3756 - accuracy: 0.8255
# Epoch 100/100
# 148/148 [==============================] - 0s 1ms/step - loss: 0.3764 - accuracy: 0.8232

# %%
model.evaluate(x_test, y_test)
# Out:
# 73/73 [==============================] - 0s 770us/step - loss: 0.4432 - accuracy: 0.7962
# [0.44315284490585327, 0.7962085604667664]

# %%
yp = model.predict(x_train)

# %%
yp[:5]
# Out:
# array([[0.01726115],
#        [0.05229366],
#        [0.00415596],
#        [0.00193387],
#        [0.0273079 ]], dtype=float32)

# %%
y_test[:5]
# Out:
# 2481    0
# 6784    0
# 6125    1
# 3052    0
# 4099    0
# Name: Churn, dtype: int64

# %%
y_pred = []
for element in yp:
    if element > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
y_pred[:5]
# Out:
# [0, 0, 0, 0, 0]

# %%
from sklearn.metrics import confusion_matrix , classification_report

# %%
import seaborn as sn

# %%
cm = tf.math.confusion_matrix(labels = y_train,predictions=y_pred)

plt.figure(figsize =(10,7))
sn.heatmap(cm, annot = True ,fmt ='d')
plt.xlabel('predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
print(classification_report(y_train,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88      3452
#            1       0.70      0.59      0.64      1259
#
#     accuracy                           0.82      4711
#    macro avg       0.78      0.75      0.76      4711
# weighted avg       0.82      0.82      0.82      4711
